# %%
# Replace 'YOUR_TOKEN' with your actual token
GITHUB_TOKEN = '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'  # Don't share this token with anyone

# %%
import requests
import pandas as pd
import time

# Replace 'YOUR_TOKEN' with your actual GitHub token
GITHUB_TOKEN = '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'  # e.g., GITHUB_TOKEN = 'ghp_abc123...'
BASE_URL = "https://api.github.com"
headers = {"Authorization": f"token {GITHUB_TOKEN}"}

# Function to fetch users in Delhi with over 100 followers
def fetch_users_in_delhi(min_followers=100, location="Delhi"):
    users = []
    page = 1
    while True:
        query = f"location:{location}+followers:>{min_followers}"
        url = f"{BASE_URL}/search/users?q={query}&page={page}"
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Error: {response.status_code}, {response.text}")
            break

        data = response.json()
        if 'items' not in data or not data['items']:
            print("No more users found.")
            break

        for user in data['items']:
            user_details = requests.get(user['url'], headers=headers).json()
            users.append({
                "login": user_details.get("login", ""),
                "name": user_details.get("name", ""),
                "company": (user_details.get("company") or "").strip('@').upper(),
                "location": user_details.get("location", ""),
                "email": user_details.get("email", ""),
                "hireable": user_details.get("hireable", ""),
                "bio": user_details.get("bio", ""),
                "public_repos": user_details.get("public_repos", 0),
                "followers": user_details.get("followers", 0),
                "following": user_details.get("following", 0),
                "created_at": user_details.get("created_at", "")
            })

        print(f"Fetched {len(data['items'])} users on page {page}.")
        page += 1
        time.sleep(1)  # Pause to respect rate limits

    return users

# Function to fetch repositories for each user
def fetch_user_repositories(username, max_repos=500):
    repositories = []
    page = 1
    while len(repositories) < max_repos:
        url = f"{BASE_URL}/users/{username}/repos?page={page}&per_page=100"
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.status_code}, {response.text}")
            break

        data = response.json()
        if not data:
            print(f"No repositories found for {username}.")
            break

        print(f"Found {len(data)} repositories for {username}.")

        for repo in data:
            license_key = repo.get("license", {}).get("key", "") if repo.get("license") else ""
            repositories.append({
                "login": username,
                "full_name": repo.get("full_name", ""),
                "created_at": repo.get("created_at", ""),
                "stargazers_count": repo.get("stargazers_count", 0),
                "watchers_count": repo.get("watchers_count", 0),
                "language": repo.get("language", ""),
                "has_projects": repo.get("has_projects", False),
                "has_wiki": repo.get("has_wiki", False),
                "license_name": license_key
            })

        page += 1
        time.sleep(1)  # Pause to respect rate limits

    return repositories

# Fetch users in Delhi
users = fetch_users_in_delhi(min_followers=100, location="Delhi")

# Print the number of users fetched
print(f"Fetched {len(users)} users.")

# Fetch repositories for each user
user_repos = []
for user in users:
    repos = fetch_user_repositories(user["login"])
    user_repos.extend(repos)

# Print the number of repositories fetched
print(f"Fetched {len(user_repos)} repositories.")
# Out:
# Fetched 30 users on page 1.
# Fetched 30 users on page 2.
# Fetched 30 users on page 3.
# Fetched 30 users on page 4.
# Fetched 30 users on page 5.
# Fetched 30 users on page 6.
# Fetched 30 users on page 7.
# Fetched 30 users on page 8.
# Fetched 30 users on page 9.
# Fetched 30 users on page 10.
# Fetched 30 users on page 11.
# Fetched 30 users on page 12.
# Fetched 30 users on page 13.
# Fetched 26 users on page 14.
# No more users found.
# Fetched 416 users.
# Found 52 repositories for amitshekhariitbhu.
# No repositories found for amitshekhariitbhu.
# Found 14 repositories for shradha-khapra.
# No repositories found for shradha-khapra.
# Found 14 repositories for loveBabbar.
# No repositories found for loveBabbar.
# Found 25 repositories for Nakshatra05.
# No repositories found for Nakshatra05.
# Found 35 repositories for Anuj-Kumar-Sharma.
# No repositories found for Anuj-Kumar-Sharma.
# Found 25 repositories for Ignitetechnologies.
# ...

# %%
# Fetch users in Delhi
users = fetch_users_in_delhi(min_followers=100, location="Delhi")
print(f"Fetched {len(users)} users.")

# Fetch repositories for each user
user_repos = []
for user in users:
    repos = fetch_user_repositories(user["login"])
    user_repos.extend(repos)

# Print the number of repositories fetched
print(f"Fetched {len(user_repos)} repositories.")

# Save to CSV
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print("User data saved to users.csv.")

user_repos_df = pd.DataFrame(user_repos)
user_repos_df.to_csv("repositories.csv", index=False)
print("Repository data saved to repositories.csv.")
# Out:
# Fetched 30 users on page 1.
# Fetched 30 users on page 2.
# Fetched 30 users on page 3.
# Fetched 30 users on page 4.
# Fetched 30 users on page 5.
# Fetched 30 users on page 6.
# Fetched 30 users on page 7.
# Fetched 30 users on page 8.
# Fetched 30 users on page 9.
# Fetched 30 users on page 10.
# Fetched 30 users on page 11.
# Fetched 30 users on page 12.
# Fetched 30 users on page 13.
# Fetched 26 users on page 14.
# No more users found.
# Fetched 416 users.
# Found 52 repositories for amitshekhariitbhu.
# No repositories found for amitshekhariitbhu.
# Found 14 repositories for shradha-khapra.
# No repositories found for shradha-khapra.
# Found 14 repositories for loveBabbar.
# No repositories found for loveBabbar.
# Found 25 repositories for Nakshatra05.
# No repositories found for Nakshatra05.
# Found 35 repositories for Anuj-Kumar-Sharma.
# No repositories found for Anuj-Kumar-Sharma.
# Found 25 repositories for Ignitetechnologies.
# ...

# %%
import pandas as pd

# Load the user and repository data
users_df = pd.read_csv("users.csv")
repositories_df = pd.read_csv("repositories.csv")

# Overview of user data
print(users_df.describe())

# Find users with the most followers
top_followers = users_df.nlargest(10, 'followers')
print("Top 10 Users by Followers:")
print(top_followers[['login', 'followers', 'name']])

# Find the most popular repositories (by stars)
popular_repos = repositories_df.nlargest(10, 'stargazers_count')
print("Top 10 Popular Repositories:")
print(popular_repos[['full_name', 'stargazers_count', 'language']])

# Language distribution of repositories
language_distribution = repositories_df['language'].value_counts()
print("Language Distribution:")
print(language_distribution)
# Out:
#        public_repos    followers     following
# count    416.000000   416.000000    416.000000
# mean      83.262019   374.187500    198.915865
# std      278.171926   808.397673   1608.606295
# min        0.000000   101.000000      0.000000
# 25%       28.750000   128.750000      7.000000
# 50%       49.000000   180.000000     46.000000
# 75%       87.250000   310.250000    134.500000
# max     5543.000000  7950.000000  32460.000000
# Top 10 Users by Followers:
#                     login  followers               name
# 0       amitshekhariitbhu       7950       AMIT SHEKHAR
# 1          shradha-khapra       7363     Shradha Khapra
# 2              loveBabbar       6651        love babbar
# 3             Nakshatra05       6640     Nakshatra Goel
# 4       Anuj-Kumar-Sharma       4926  Anuj Kumar Sharma
# 5      Ignitetechnologies       4559  Hacking Articles
# 6  developerrahulofficial       3982    Developer Rahul
# 7            farhan7reza7       2456        Farhan Reza
# ...

# %%
from google.colab import files

# Download the users.csv file
files.download("users.csv")

# Download the repositories.csv file
files.download("repositories.csv")

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv("users.csv")
repositories_df = pd.read_csv("repositories.csv")

# Check for missing values in users.csv
print("Missing values in users.csv:")
print(users_df.isnull().sum())

# Check for missing values in repositories.csv
print("\nMissing values in repositories.csv:")
print(repositories_df.isnull().sum())
# Out:
# Missing values in users.csv:
# login             0
# name              0
# company         164
# location          0
# email           220
# hireable        257
# bio              38
# public_repos      0
# followers         0
# following         0
# created_at        0
# dtype: int64
#
# Missing values in repositories.csv:
# login                   0
# full_name               0
# created_at              0
# stargazers_count        0
# watchers_count          0
# language             8554
# has_projects            0
# has_wiki                0
# license_name        19418
# dtype: int64

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv("users.csv")
repositories_df = pd.read_csv("repositories.csv")

# Check for missing values in users.csv
print("Missing values in users.csv:")
print(users_df.isnull().sum())

# Check for missing values in repositories.csv
print("\nMissing values in repositories.csv:")
print(repositories_df.isnull().sum())
# Out:
# Missing values in users.csv:
# login             0
# name              0
# company         164
# location          0
# email           220
# hireable          0
# bio              38
# public_repos      0
# followers         0
# following         0
# created_at        0
# dtype: int64
#
# Missing values in repositories.csv:
# login                   0
# full_name               0
# created_at              0
# stargazers_count        0
# watchers_count          0
# language                0
# has_projects            0
# has_wiki                0
# license_name        19418
# dtype: int64

# %%
# Fill missing values in users_df
users_df.fillna({
    "company": "",  # Empty string for company
    "email": "",    # Empty string for email
    "hireable": "false",  # Fill with 'false' if hireable is missing
    "bio": "",      # Empty string for bio
}, inplace=True)

# Fill missing values in repositories_df
repositories_df.fillna({
    "language": "Unknown",  # Placeholder for unknown languages
    "license_name": "",      # Empty string for license
}, inplace=True)

# %%
# Drop rows with any missing values in users_df
users_df.dropna(inplace=True)

# Drop rows with any missing values in repositories_df
repositories_df.dropna(inplace=True)

# %%
# Save the cleaned DataFrames
users_df.to_csv("users_cleaned.csv", index=False)
repositories_df.to_csv("repositories_cleaned.csv", index=False)

print("Cleaned data saved to users_cleaned.csv and repositories_cleaned.csv.")
# Out:
# Cleaned data saved to users_cleaned.csv and repositories_cleaned.csv.

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv("users.csv")
repositories_df = pd.read_csv("repositories.csv")

# Check for missing values in users.csv
print("Missing values in users.csv:")
print(users_df.isnull().sum())

# Check for missing values in repositories.csv
print("\nMissing values in repositories.csv:")
print(repositories_df.isnull().sum())
# Out:
# Missing values in users.csv:
# login           0
# name            0
# company         0
# location        0
# email           0
# hireable        0
# bio             0
# public_repos    0
# followers       0
# following       0
# created_at      0
# dtype: int64
#
# Missing values in repositories.csv:
# login               0
# full_name           0
# created_at          0
# stargazers_count    0
# watchers_count      0
# language            0
# has_projects        0
# has_wiki            0
# license_name        0
# dtype: int64

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv('users.csv')
repositories_df = pd.read_csv('repositories.csv')

# Handle missing values in users.csv
users_df['company'].fillna('UNKNOWN', inplace=True)  # Replace missing companies
users_df['email'].fillna('NOT PROVIDED', inplace=True)  # Replace missing emails
users_df['bio'].fillna('NO BIO AVAILABLE', inplace=True)  # Replace missing bios

# Handle missing values in repositories.csv
repositories_df['license_name'].fillna('NO LICENSE', inplace=True)  # Replace missing licenses

# Save the updated DataFrames back to CSV
users_df.to_csv('users.csv', index=False)
repositories_df.to_csv('repositories.csv', index=False)

print("Missing values handled and CSV files updated.")
# Out:
# Missing values handled and CSV files updated.
# <ipython-input-64-26ef37bae956>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   users_df['company'].fillna('UNKNOWN', inplace=True)  # Replace missing companies
# <ipython-input-64-26ef37bae956>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import pandas as pd

# Load repositories.csv
repositories_df = pd.read_csv("repositories.csv")

# Filter out rows with missing license_name
repositories_df = repositories_df[repositories_df['license_name'].notna()]

# Count the occurrences of each license
license_counts = repositories_df['license_name'].value_counts()

# Get the top 3 licenses
top_licenses = license_counts.head(3)

# Get the license names in a comma-separated format
top_license_names = ', '.join(top_licenses.index)
print(top_license_names)
# Out:
# NO LICENSE, mit, apache-2.0

# %%
import pandas as pd

# Load users.csv
users_df = pd.read_csv("users.csv")

# Clean up the company field
users_df['company'] = users_df['company'].str.strip().str.replace(r'^@', '', regex=True).str.upper()

# Count occurrences of each company, ignoring NaN values
company_counts = users_df['company'].value_counts()

# Get the most common company
most_common_company = company_counts.idxmax()
most_common_count = company_counts.max()

print(f"The majority of these developers work at: {most_common_company} (Count: {most_common_count})")
# Out:
# The majority of these developers work at: UNKNOWN (Count: 164)

# %%
import pandas as pd

# Load repositories.csv
repositories_df = pd.read_csv("repositories.csv")

# Count occurrences of each language, ignoring NaN values
language_counts = repositories_df['language'].value_counts()

# Get the most popular programming language
most_popular_language = language_counts.idxmax()
most_popular_count = language_counts.max()

print(f"The most popular programming language among these users is: {most_popular_language} (Count: {most_popular_count})")
# Out:
# The most popular programming language among these users is: Unknown (Count: 8554)

# %%
import pandas as pd

# Load the CSV files
users_df = pd.read_csv("users.csv")
repositories_df = pd.read_csv("repositories.csv")

# Convert created_at to datetime for filtering
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Filter users who joined after 2020
filtered_users = users_df[users_df['created_at'] > '2020-01-01']

# Merge filtered users with their repositories
merged_df = pd.merge(filtered_users, repositories_df, on='login')

# Count occurrences of each language, ignoring NaN values
language_counts = merged_df['language'].value_counts()

# Get the second most popular programming language
second_most_popular_language = language_counts.index[1]  # Index 1 for second most
second_most_popular_count = language_counts.iloc[1]

print(f"The second most popular programming language among users who joined after 2020 is: {second_most_popular_language} (Count: {second_most_popular_count})")
# Out:
# The second most popular programming language among users who joined after 2020 is: Unknown (Count: 2282)

# %%
import pandas as pd

# Load the repositories.csv file
repositories_df = pd.read_csv("repositories.csv")

# Group by language and calculate the average stargazers_count
average_stars = repositories_df.groupby('language')['stargazers_count'].mean()

# Identify the language with the highest average number of stars
highest_avg_stars_language = average_stars.idxmax()
highest_avg_stars_count = average_stars.max()

print(f"The language with the highest average number of stars per repository is: {highest_avg_stars_language} (Average Stars: {highest_avg_stars_count})")
# Out:
# The language with the highest average number of stars per repository is: Svelte (Average Stars: 101.45)

# %%
import pandas as pd

# Load the users.csv file
users_df = pd.read_csv("users.csv")

# Calculate leader_strength
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort by leader_strength and get the top 5
top_leaders = users_df.nlargest(5, 'leader_strength')

# Extract logins
top_leader_logins = ', '.join(top_leaders['login'])

print(f"Top 5 users by leader strength: {top_leader_logins}")
# Out:
# Top 5 users by leader strength: Anuj-Kumar-Sharma, Ignitetechnologies, shradha-khapra, loveBabbar, amitshekhariitbhu

# %%
import pandas as pd

# Load the users.csv file
users_df = pd.read_csv("users.csv")

# Calculate correlation between followers and public_repos
correlation = users_df['followers'].corr(users_df['public_repos'])

# Format the correlation to 3 decimal places
correlation_rounded = round(correlation, 3)

print(f"Correlation between followers and public repositories: {correlation_rounded}")
# Out:
# Correlation between followers and public repositories: -0.017

# %%
import pandas as pd
import statsmodels.api as sm

# Load the users.csv file
users_df = pd.read_csv("users.csv")

# Prepare the data for regression
X = users_df['public_repos']  # Independent variable
y = users_df['followers']      # Dependent variable

# Add a constant to the independent variable (for intercept)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the slope (coefficient for public_repos)
slope = model.params['public_repos']

# Format the slope to 3 decimal places
slope_rounded = round(slope, 3)

print(f"Regression slope of followers on repos: {slope_rounded}")
# Out:
# Regression slope of followers on repos: -0.049

# %%
print(repositories_df[['has_projects', 'has_wiki']].value_counts())
# Out:
# has_projects  has_wiki
# 1             1           26950
#               0            2388
# 0             0              78
#               1               8
# Name: count, dtype: int64

# %%
print(repositories_df['has_projects'].unique())
print(repositories_df['has_wiki'].unique())
# Out:
# [1 0]
# [1 0]

# %%
# Check for missing values in the relevant columns
missing_counts = repositories_df[['has_projects', 'has_wiki']].isnull().sum()
print("Missing values in has_projects and has_wiki:\n", missing_counts)

# If there are no missing values, proceed to calculate the correlation
if missing_counts.sum() == 0:
    # Calculate correlation between has_projects and has_wiki
    correlation = repositories_df[['has_projects', 'has_wiki']].corr().iloc[0, 1]
    correlation_rounded = round(correlation, 3)
    print(f"Correlation between projects and wiki enabled: {correlation_rounded}")
else:
    print("There are missing values in the relevant columns, so correlation cannot be calculated.")
# Out:
# Missing values in has_projects and has_wiki:
#  has_projects    0
# has_wiki        0
# dtype: int64
# Correlation between projects and wiki enabled: 0.161

# %%
# Check for missing values in the relevant columns
missing_counts = repositories_df[['has_projects', 'has_wiki']].isnull().sum()
print("Missing values in has_projects and has_wiki:\n", missing_counts)

# If there are no missing values, proceed to calculate the correlation
if missing_counts.sum() == 0:
    # Calculate correlation between has_projects and has_wiki
    correlation = repositories_df[['has_projects', 'has_wiki']].corr().iloc[0, 1]
    correlation_rounded = correlation
    print(f"Correlation between projects and wiki enabled: {correlation_rounded}")
else:
    print("There are missing values in the relevant columns, so correlation cannot be calculated.")
# Out:
# Missing values in has_projects and has_wiki:
#  has_projects    0
# has_wiki        0
# dtype: int64
# Correlation between projects and wiki enabled: 0.16083611997886516

# %%
import statsmodels.api as sm

# Filter out users with empty bios and calculate bio word count
users_with_bio = users_df[users_df['bio'].notna()]
users_with_bio['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split()))

# Define the independent variable (bio word count) and the dependent variable (followers)
X = users_with_bio['bio_word_count']
y = users_with_bio['followers']

# Add a constant for the regression model
X = sm.add_constant(X)

# Perform the linear regression
model = sm.OLS(y, X).fit()
slope = round(model.params['bio_word_count'], 3)

print(f"Regression slope of followers on bio word count: {slope}")
# Out:
# Regression slope of followers on bio word count: 12.723

# %%
# Convert 'created_at' to datetime if it's not already
repositories_df['created_at'] = pd.to_datetime(repositories_df['created_at'])

# Extract the day of the week (5 = Saturday, 6 = Sunday)
repositories_df['weekday'] = repositories_df['created_at'].dt.weekday

# Filter for weekends (Saturday and Sunday)
weekend_repos = repositories_df[repositories_df['weekday'].isin([5, 6])]

# Count repositories created on weekends by each user
weekend_repo_counts = weekend_repos['login'].value_counts().head(5)

# Get the top 5 users by weekend repo count
top_weekend_users = ','.join(weekend_repo_counts.index)
print(f"Top 5 users by repositories created on weekends: {top_weekend_users}")
# Out:
# Top 5 users by repositories created on weekends: dheeraj-thedev,imvickykumar999,coding-blocks-archives,Ayush7614,cybergeekgyan

# %%
# Calculate the correlation between has_projects and has_wiki
projects_wiki_corr = repositories_df['has_projects'].corr(repositories_df['has_wiki'])

# Display the correlation, rounded to 3 decimal places
print(f"Correlation between projects and wiki enabled: {projects_wiki_corr:.3f}")
# Out:
# Correlation between projects and wiki enabled: 0.161

# %%
# Filter and count users with emails for each hireable status
hireable_with_email = users_df[(users_df['hireable'] == True) & (users_df['email'] != '')].shape[0]
non_hireable_with_email = users_df[(users_df['hireable'] != True) & (users_df['email'] != '')].shape[0]

# Total counts of hireable and non-hireable users
hireable_total = users_df[users_df['hireable'] == True].shape[0]
non_hireable_total = users_df[users_df['hireable'] != True].shape[0]

# Calculate fractions, handling any cases where count could be zero to avoid errors
fraction_hireable = hireable_with_email / hireable_total if hireable_total > 0 else 0
fraction_non_hireable = non_hireable_with_email / non_hireable_total if non_hireable_total > 0 else 0

# Difference between hireable and non-hireable fractions
difference = fraction_hireable - fraction_non_hireable
difference
# Out:
# 0.0

# %%
# Check the counts in each category
hireable_with_email = users_df[(users_df['hireable'] == True) & (users_df['email'] != '')].shape[0]
hireable_without_email = users_df[(users_df['hireable'] == True) & (users_df['email'] == '')].shape[0]
non_hireable_with_email = users_df[(users_df['hireable'] != True) & (users_df['email'] != '')].shape[0]
non_hireable_without_email = users_df[(users_df['hireable'] != True) & (users_df['email'] == '')].shape[0]

# Display counts
print("Hireable with email:", hireable_with_email)
print("Hireable without email:", hireable_without_email)
print("Non-hireable with email:", non_hireable_with_email)
print("Non-hireable without email:", non_hireable_without_email)
# Out:
# Hireable with email: 159
# Hireable without email: 0
# Non-hireable with email: 257
# Non-hireable without email: 0

# %%
import pandas as pd

def analyze_email_sharing(users_csv_path='users.csv'):
    # Read the complete CSV file
    df = pd.read_csv(users_csv_path)

    # Convert email column to boolean (True if email exists, False if NaN or empty)
    df['has_email'] = df['email'].notna() & (df['email'] != '')

    # Calculate for hireable users
    hireable_mask = df['hireable'] == True
    if hireable_mask.any():
        hireable_email_fraction = df[hireable_mask]['has_email'].mean()
    else:
        hireable_email_fraction = 0

    # Calculate for non-hireable users
    non_hireable_mask = df['hireable'] != True
    if non_hireable_mask.any():
        non_hireable_email_fraction = df[non_hireable_mask]['has_email'].mean()
    else:
        non_hireable_email_fraction = 0

    # Calculate difference and round to 3 decimal places
    difference = round(hireable_email_fraction - non_hireable_email_fraction, 3)

    # Print debug information
    print(f"Total users: {len(df)}")
    print(f"Hireable users with email: {df[hireable_mask]['has_email'].sum()}/{hireable_mask.sum()}")
    print(f"Non-hireable users with email: {df[non_hireable_mask]['has_email'].sum()}/{non_hireable_mask.sum()}")
    print(f"Hireable fraction: {hireable_email_fraction:.3f}")
    print(f"Non-hireable fraction: {non_hireable_email_fraction:.3f}")

    return difference

# Read and analyze the complete dataset
result = analyze_email_sharing()
print(f"\nFinal result: {result:.3f}")
# Out:
# Total users: 416
# Hireable users with email: 159/159
# Non-hireable users with email: 257/257
# Hireable fraction: 1.000
# Non-hireable fraction: 1.000
#
# Final result: 0.000
